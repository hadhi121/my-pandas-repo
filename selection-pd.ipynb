# %%
import pandas as pd

df = pd.read_csv('pokemon.csv',index_col='Name')
print(df.to_string())#it will show all the table
# Out:
#              No     Type1     Type2  Height  Weight  Legendary
# Name
# Bulbasaur     1     Grass    Poison     0.7     6.9          0
# Ivysaur       2     Grass    Poison     1.0    13.0          0
# Venusaur      3     Grass    Poison     2.0   100.0          0
# Charmander    4      Fire       NaN     0.6     8.5          0
# Charmeleon    5      Fire       NaN     1.1    19.0          0
# Charizard     6      Fire    Flying     1.7    90.5          0
# Squirtle      7     Water       NaN     0.5     9.0          0
# Wartortle     8     Water       NaN     1.0    22.5          0
# Blastoise     9     Water       NaN     1.6    85.5          0
# Caterpie     10       Bug       NaN     0.3     2.9          0
# Metapod      11       Bug       NaN     0.7     9.9          0
# Butterfree   12       Bug    Flying     1.1    32.0          0
# Weedle       13       Bug    Poison     0.3     3.2          0
# Kakuna       14       Bug    Poison     0.6    10.0          0
# ...

# %%
#selecting multiple col
df[['Height','Weight']]
# Out:
#             Height  Weight
# Name
# Bulbasaur      0.7     6.9
# Ivysaur        1.0    13.0
# Venusaur       2.0   100.0
# Charmander     0.6     8.5
# Charmeleon     1.1    19.0
# ...            ...     ...
# Dragonair      4.0    16.5
# Dragonite      2.2   210.0
# Mewtwo         2.0   122.0
# Mewtwo         2.0   122.0
# Mewtwo         2.0   122.0
#
# [152 rows x 2 columns]

# %%
#print(df.loc['Pikachu'])
print(df.loc['Charizard',['Height','Weight']])#can access the only detail we want
# Out:
# No                 25
# Type1        Electric
# Type2             NaN
# Height            0.4
# Weight            6.0
# Legendary           0
# Name: Pikachu, dtype: object
# Height     1.7
# Weight    90.5
# Name: Charizard, dtype: object

# %%
#selecting a range of row(not one row)
print(df.loc['Charizard':'Blastoise',['Height','Weight']])
# Out:
#            Height  Weight
# Name
# Charizard     1.7    90.5
# Squirtle      0.5     9.0
# Wartortle     1.0    22.5
# Blastoise     1.6    85.5

# %%
print(df.iloc[0:3 , 1:])
# Out:
#            Type1   Type2  Height  Weight  Legendary
# Name
# Bulbasaur  Grass  Poison     0.7     6.9          0
# Ivysaur    Grass  Poison     1.0    13.0          0
# Venusaur   Grass  Poison     2.0   100.0          0

# %%
pokemon = input('enter a pokemon name: ')
try:
    print(df.loc[pokemon])
except KeyError:
    print(f'{pokemon} does not exist.')
